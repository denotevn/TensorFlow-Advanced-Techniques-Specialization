# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)
print(df.head())
# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)
# Out:
#      X1     X2     X3      X4   X5  X6    X7  X8     Y1     Y2
# 0  0.69  735.0  294.0  220.50  3.5   3  0.25   3  12.46  14.38
# 1  0.98  514.5  294.0  110.25  7.0   5  0.10   3  24.35  26.14
# 2  0.76  661.5  416.5  122.50  7.0   2  0.10   1  32.96  33.87
# 3  0.69  735.0  294.0  220.50  3.5   5  0.25   5  12.47  14.60
# 4  0.90  563.5  318.5  122.50  7.0   2  0.25   5  33.13  32.25

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
print(len(train.columns))
# Out:
# 8

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 1ms/sample - loss: 291.0519 - y1_output_loss: 136.6880 - y2_output_loss: 151.7046 - y1_output_root_mean_squared_error: 11.7463 - y2_output_root_mean_squared_error: 12.3724 - val_loss: 33.1097 - val_y1_output_loss: 16.8789 - val_y2_output_loss: 17.1739 - val_y1_output_root_mean_squared_error: 3.9949 - val_y2_output_root_mean_squared_error: 4.1413
# Epoch 2/500
# 614/614 [==============================] - 0s 139us/sample - loss: 34.4118 - y1_output_loss: 12.5817 - y2_output_loss: 21.6177 - y1_output_root_mean_squared_error: 3.5599 - y2_output_root_mean_squared_error: 4.6625 - val_loss: 31.7989 - val_y1_output_loss: 11.2629 - val_y2_output_loss: 19.7462 - val_y1_output_root_mean_squared_error: 3.3671 - val_y2_output_root_mean_squared_error: 4.5234
# Epoch 3/500
# 614/614 [==============================] - 0s 158us/sample - loss: 31.8104 - y1_output_loss: 10.8369 - y2_output_loss: 20.8418 - y1_output_root_mean_squared_error: 3.3042 - y2_output_root_mean_squared_error: 4.5709 - val_loss: 19.2147 - val_y1_output_loss: 8.6164 - val_y2_output_loss: 10.5922 - val_y1_output_root_mean_squared_error: 2.9137 - val_y2_output_root_mean_squared_error: 3.2749
# Epoch 4/500
# 614/614 [==============================] - 0s 137us/sample - loss: 23.3318 - y1_output_loss: 9.2731 - y2_output_loss: 13.9940 - y1_output_root_mean_squared_error: 3.0451 - y2_output_root_mean_squared_error: 3.7495 - val_loss: 19.3387 - val_y1_output_loss: 8.9597 - val_y2_output_loss: 10.3831 - val_y1_output_root_mean_squared_error: 2.9870 - val_y2_output_root_mean_squared_error: 3.2275
# Epoch 5/500
# 614/614 [==============================] - 0s 141us/sample - loss: 24.5584 - y1_output_loss: 9.1990 - y2_output_loss: 15.3562 - y1_output_root_mean_squared_error: 3.0442 - y2_output_root_mean_squared_error: 3.9104 - val_loss: 28.8720 - val_y1_output_loss: 8.5706 - val_y2_output_loss: 19.6092 - val_y1_output_root_mean_squared_error: 2.9252 - val_y2_output_root_mean_squared_error: 4.5072
# Epoch 6/500
# 614/614 [==============================] - 0s 147us/sample - loss: 24.1292 - y1_output_loss: 9.0457 - y2_output_loss: 14.9279 - y1_output_root_mean_squared_error: 3.0217 - y2_output_root_mean_squared_error: 3.8728 - val_loss: 24.5566 - val_y1_output_loss: 8.9003 - val_y2_output_loss: 15.0751 - val_y1_output_root_mean_squared_error: 2.9920 - val_y2_output_root_mean_squared_error: 3.9503
# Epoch 7/500
# 614/614 [==============================] - 0s 143us/sample - loss: 23.1540 - y1_output_loss: 8.7164 - y2_output_loss: 14.6811 - y1_output_root_mean_squared_error: 2.9518 - y2_output_root_mean_squared_error: 3.8001 - val_loss: 23.4823 - val_y1_output_loss: 7.6945 - val_y2_output_loss: 16.1428 - val_y1_output_root_mean_squared_error: 2.7464 - val_y2_output_root_mean_squared_error: 3.9925
# Epoch 8/500
# 614/614 [==============================] - 0s 141us/sample - loss: 24.0065 - y1_output_loss: 8.9266 - y2_output_loss: 14.8992 - y1_output_root_mean_squared_error: 2.9987 - y2_output_root_mean_squared_error: 3.8748 - val_loss: 17.3921 - val_y1_output_loss: 7.5856 - val_y2_output_loss: 9.8885 - val_y1_output_root_mean_squared_error: 2.7391 - val_y2_output_root_mean_squared_error: 3.1448
# Epoch 9/500
# 614/614 [==============================] - 0s 139us/sample - loss: 20.1753 - y1_output_loss: 7.7950 - y2_output_loss: 12.6378 - y1_output_root_mean_squared_error: 2.7888 - y2_output_root_mean_squared_error: 3.5210 - val_loss: 50.1817 - val_y1_output_loss: 10.9538 - val_y2_output_loss: 37.6207 - val_y1_output_root_mean_squared_error: 3.3704 - val_y2_output_root_mean_squared_error: 6.2308
# Epoch 10/500
# 614/614 [==============================] - 0s 132us/sample - loss: 21.1594 - y1_output_loss: 7.8954 - y2_output_loss: 13.1336 - y1_output_root_mean_squared_error: 2.8127 - y2_output_root_mean_squared_error: 3.6398 - val_loss: 14.1928 - val_y1_output_loss: 6.4625 - val_y2_output_loss: 7.6899 - val_y1_output_root_mean_squared_error: 2.5203 - val_y2_output_root_mean_squared_error: 2.8002
# Epoch 11/500
# 614/614 [==============================] - 0s 145us/sample - loss: 18.0030 - y1_output_loss: 7.2419 - y2_output_loss: 10.7051 - y1_output_root_mean_squared_error: 2.6980 - y2_output_root_mean_squared_error: 3.2747 - val_loss: 23.7847 - val_y1_output_loss: 7.4427 - val_y2_output_loss: 16.4122 - val_y1_output_root_mean_squared_error: 2.7153 - val_y2_output_root_mean_squared_error: 4.0511
# Epoch 12/500
# 614/614 [==============================] - 0s 135us/sample - loss: 20.7294 - y1_output_loss: 7.6450 - y2_output_loss: 13.2069 - y1_output_root_mean_squared_error: 2.7665 - y2_output_root_mean_squared_error: 3.6160 - val_loss: 34.8413 - val_y1_output_loss: 9.4266 - val_y2_output_loss: 25.2097 - val_y1_output_root_mean_squared_error: 3.0627 - val_y2_output_root_mean_squared_error: 5.0459
# Epoch 13/500
# 614/614 [==============================] - 0s 129us/sample - loss: 17.8831 - y1_output_loss: 6.9241 - y2_output_loss: 11.0159 - y1_output_root_mean_squared_error: 2.6339 - y2_output_root_mean_squared_error: 3.3084 - val_loss: 28.6999 - val_y1_output_loss: 7.3021 - val_y2_output_loss: 21.7383 - val_y1_output_root_mean_squared_error: 2.6669 - val_y2_output_root_mean_squared_error: 4.6463
# Epoch 14/500
# 614/614 [==============================] - 0s 131us/sample - loss: 18.4332 - y1_output_loss: 6.8657 - y2_output_loss: 11.4222 - y1_output_root_mean_squared_error: 2.6304 - y2_output_root_mean_squared_error: 3.3933 - val_loss: 11.7893 - val_y1_output_loss: 5.3390 - val_y2_output_loss: 6.2745 - val_y1_output_root_mean_squared_error: 2.3100 - val_y2_output_root_mean_squared_error: 2.5403
# Epoch 15/500
# 614/614 [==============================] - 0s 131us/sample - loss: 20.5686 - y1_output_loss: 7.4367 - y2_output_loss: 13.0256 - y1_output_root_mean_squared_error: 2.7320 - y2_output_root_mean_squared_error: 3.6200 - val_loss: 28.2569 - val_y1_output_loss: 6.9810 - val_y2_output_loss: 21.2130 - val_y1_output_root_mean_squared_error: 2.6268 - val_y2_output_root_mean_squared_error: 4.6213
# Epoch 16/500
# 614/614 [==============================] - 0s 146us/sample - loss: 16.0307 - y1_output_loss: 6.6121 - y2_output_loss: 9.5615 - y1_output_root_mean_squared_error: 2.5482 - y2_output_root_mean_squared_error: 3.0882 - val_loss: 23.4939 - val_y1_output_loss: 6.4651 - val_y2_output_loss: 16.2539 - val_y1_output_root_mean_squared_error: 2.5784 - val_y2_output_root_mean_squared_error: 4.1043
# Epoch 17/500
# 614/614 [==============================] - 0s 134us/sample - loss: 16.7506 - y1_output_loss: 6.4470 - y2_output_loss: 10.1636 - y1_output_root_mean_squared_error: 2.5503 - y2_output_root_mean_squared_error: 3.2010 - val_loss: 15.3081 - val_y1_output_loss: 5.1605 - val_y2_output_loss: 10.1429 - val_y1_output_root_mean_squared_error: 2.2712 - val_y2_output_root_mean_squared_error: 3.1859
# Epoch 18/500
# 614/614 [==============================] - 0s 136us/sample - loss: 15.1004 - y1_output_loss: 5.5073 - y2_output_loss: 9.8018 - y1_output_root_mean_squared_error: 2.3360 - y2_output_root_mean_squared_error: 3.1054 - val_loss: 11.1069 - val_y1_output_loss: 5.1239 - val_y2_output_loss: 5.9866 - val_y1_output_root_mean_squared_error: 2.2422 - val_y2_output_root_mean_squared_error: 2.4656
# Epoch 19/500
# 614/614 [==============================] - 0s 134us/sample - loss: 13.4427 - y1_output_loss: 5.3094 - y2_output_loss: 8.0456 - y1_output_root_mean_squared_error: 2.3146 - y2_output_root_mean_squared_error: 2.8435 - val_loss: 9.5946 - val_y1_output_loss: 4.4828 - val_y2_output_loss: 5.1562 - val_y1_output_root_mean_squared_error: 2.0914 - val_y2_output_root_mean_squared_error: 2.2848
# Epoch 20/500
# 614/614 [==============================] - 0s 129us/sample - loss: 14.5367 - y1_output_loss: 5.8038 - y2_output_loss: 8.7160 - y1_output_root_mean_squared_error: 2.4096 - y2_output_root_mean_squared_error: 2.9548 - val_loss: 10.5800 - val_y1_output_loss: 5.0345 - val_y2_output_loss: 5.3755 - val_y1_output_root_mean_squared_error: 2.2714 - val_y2_output_root_mean_squared_error: 2.3283
# Epoch 21/500
# 614/614 [==============================] - 0s 132us/sample - loss: 12.9677 - y1_output_loss: 5.0479 - y2_output_loss: 7.8083 - y1_output_root_mean_squared_error: 2.2560 - y2_output_root_mean_squared_error: 2.8068 - val_loss: 18.8293 - val_y1_output_loss: 5.7631 - val_y2_output_loss: 13.2334 - val_y1_output_root_mean_squared_error: 2.3682 - val_y2_output_root_mean_squared_error: 3.6361
# Epoch 22/500
# 614/614 [==============================] - 0s 132us/sample - loss: 11.4729 - y1_output_loss: 4.5852 - y2_output_loss: 6.8529 - y1_output_root_mean_squared_error: 2.1366 - y2_output_root_mean_squared_error: 2.6283 - val_loss: 8.0639 - val_y1_output_loss: 3.9019 - val_y2_output_loss: 4.1538 - val_y1_output_root_mean_squared_error: 1.9615 - val_y2_output_root_mean_squared_error: 2.0534
# Epoch 23/500
# 614/614 [==============================] - 0s 129us/sample - loss: 14.1055 - y1_output_loss: 4.7472 - y2_output_loss: 9.2344 - y1_output_root_mean_squared_error: 2.1881 - y2_output_root_mean_squared_error: 3.0525 - val_loss: 8.7986 - val_y1_output_loss: 3.7286 - val_y2_output_loss: 5.1192 - val_y1_output_root_mean_squared_error: 1.9165 - val_y2_output_root_mean_squared_error: 2.2639
# Epoch 24/500
# 614/614 [==============================] - 0s 149us/sample - loss: 13.7406 - y1_output_loss: 4.8650 - y2_output_loss: 8.8543 - y1_output_root_mean_squared_error: 2.2086 - y2_output_root_mean_squared_error: 2.9770 - val_loss: 11.4019 - val_y1_output_loss: 3.8085 - val_y2_output_loss: 7.2766 - val_y1_output_root_mean_squared_error: 1.9697 - val_y2_output_root_mean_squared_error: 2.7426
# Epoch 25/500
# 614/614 [==============================] - 0s 140us/sample - loss: 13.7917 - y1_output_loss: 4.5289 - y2_output_loss: 9.1844 - y1_output_root_mean_squared_error: 2.1293 - y2_output_root_mean_squared_error: 3.0427 - val_loss: 7.8601 - val_y1_output_loss: 3.4894 - val_y2_output_loss: 4.3077 - val_y1_output_root_mean_squared_error: 1.8517 - val_y2_output_root_mean_squared_error: 2.1051
# Epoch 26/500
# 614/614 [==============================] - 0s 139us/sample - loss: 10.9508 - y1_output_loss: 3.8929 - y2_output_loss: 7.0135 - y1_output_root_mean_squared_error: 1.9807 - y2_output_root_mean_squared_error: 2.6509 - val_loss: 6.9753 - val_y1_output_loss: 3.0031 - val_y2_output_loss: 4.0145 - val_y1_output_root_mean_squared_error: 1.7158 - val_y2_output_root_mean_squared_error: 2.0078
# Epoch 27/500
# 614/614 [==============================] - 0s 130us/sample - loss: 13.2483 - y1_output_loss: 4.1397 - y2_output_loss: 9.0050 - y1_output_root_mean_squared_error: 2.0394 - y2_output_root_mean_squared_error: 3.0148 - val_loss: 6.4631 - val_y1_output_loss: 2.7701 - val_y2_output_loss: 3.6265 - val_y1_output_root_mean_squared_error: 1.6618 - val_y2_output_root_mean_squared_error: 1.9239
# Epoch 28/500
# 614/614 [==============================] - 0s 139us/sample - loss: 11.4977 - y1_output_loss: 4.0375 - y2_output_loss: 7.3679 - y1_output_root_mean_squared_error: 2.0187 - y2_output_root_mean_squared_error: 2.7244 - val_loss: 7.2488 - val_y1_output_loss: 2.6566 - val_y2_output_loss: 4.4418 - val_y1_output_root_mean_squared_error: 1.6426 - val_y2_output_root_mean_squared_error: 2.1333
# Epoch 29/500
# 614/614 [==============================] - 0s 131us/sample - loss: 11.5999 - y1_output_loss: 4.0109 - y2_output_loss: 7.5843 - y1_output_root_mean_squared_error: 2.0059 - y2_output_root_mean_squared_error: 2.7525 - val_loss: 7.7196 - val_y1_output_loss: 3.4859 - val_y2_output_loss: 4.2944 - val_y1_output_root_mean_squared_error: 1.8384 - val_y2_output_root_mean_squared_error: 2.0832
# Epoch 30/500
# 614/614 [==============================] - 0s 132us/sample - loss: 8.9490 - y1_output_loss: 3.0973 - y2_output_loss: 5.8752 - y1_output_root_mean_squared_error: 1.7642 - y2_output_root_mean_squared_error: 2.4159 - val_loss: 18.5159 - val_y1_output_loss: 4.8340 - val_y2_output_loss: 13.0426 - val_y1_output_root_mean_squared_error: 2.2382 - val_y2_output_root_mean_squared_error: 3.6751
# Epoch 31/500
# 614/614 [==============================] - 0s 133us/sample - loss: 11.1360 - y1_output_loss: 3.3520 - y2_output_loss: 7.7193 - y1_output_root_mean_squared_error: 1.8383 - y2_output_root_mean_squared_error: 2.7851 - val_loss: 16.2108 - val_y1_output_loss: 3.7412 - val_y2_output_loss: 12.7119 - val_y1_output_root_mean_squared_error: 1.8858 - val_y2_output_root_mean_squared_error: 3.5573
# Epoch 32/500
# 614/614 [==============================] - 0s 134us/sample - loss: 10.8259 - y1_output_loss: 3.5462 - y2_output_loss: 7.3172 - y1_output_root_mean_squared_error: 1.8895 - y2_output_root_mean_squared_error: 2.6936 - val_loss: 11.3357 - val_y1_output_loss: 4.0516 - val_y2_output_loss: 7.5078 - val_y1_output_root_mean_squared_error: 1.9823 - val_y2_output_root_mean_squared_error: 2.7214
# Epoch 33/500
# 614/614 [==============================] - 0s 133us/sample - loss: 10.2037 - y1_output_loss: 3.4073 - y2_output_loss: 6.7189 - y1_output_root_mean_squared_error: 1.8512 - y2_output_root_mean_squared_error: 2.6032 - val_loss: 5.6759 - val_y1_output_loss: 2.3174 - val_y2_output_loss: 3.2410 - val_y1_output_root_mean_squared_error: 1.5255 - val_y2_output_root_mean_squared_error: 1.8300
# Epoch 34/500
# 614/614 [==============================] - 0s 139us/sample - loss: 11.6412 - y1_output_loss: 3.7252 - y2_output_loss: 7.9262 - y1_output_root_mean_squared_error: 1.9350 - y2_output_root_mean_squared_error: 2.8102 - val_loss: 8.9036 - val_y1_output_loss: 3.5647 - val_y2_output_loss: 5.0693 - val_y1_output_root_mean_squared_error: 1.9100 - val_y2_output_root_mean_squared_error: 2.2925
# Epoch 35/500
# 614/614 [==============================] - 0s 146us/sample - loss: 9.0772 - y1_output_loss: 2.9071 - y2_output_loss: 6.1952 - y1_output_root_mean_squared_error: 1.7097 - y2_output_root_mean_squared_error: 2.4807 - val_loss: 6.6997 - val_y1_output_loss: 2.9241 - val_y2_output_loss: 3.7799 - val_y1_output_root_mean_squared_error: 1.6961 - val_y2_output_root_mean_squared_error: 1.9552
# Epoch 36/500
# 614/614 [==============================] - 0s 135us/sample - loss: 8.0979 - y1_output_loss: 2.6983 - y2_output_loss: 5.3304 - y1_output_root_mean_squared_error: 1.6480 - y2_output_root_mean_squared_error: 2.3199 - val_loss: 5.4775 - val_y1_output_loss: 2.2727 - val_y2_output_loss: 3.1213 - val_y1_output_root_mean_squared_error: 1.5139 - val_y2_output_root_mean_squared_error: 1.7848
# Epoch 37/500
# 614/614 [==============================] - 0s 140us/sample - loss: 7.6546 - y1_output_loss: 2.5561 - y2_output_loss: 5.2440 - y1_output_root_mean_squared_error: 1.5745 - y2_output_root_mean_squared_error: 2.2750 - val_loss: 20.7101 - val_y1_output_loss: 4.8869 - val_y2_output_loss: 15.1289 - val_y1_output_root_mean_squared_error: 2.2426 - val_y2_output_root_mean_squared_error: 3.9599
# Epoch 38/500
# 614/614 [==============================] - 0s 133us/sample - loss: 8.2566 - y1_output_loss: 2.6975 - y2_output_loss: 5.6401 - y1_output_root_mean_squared_error: 1.6389 - y2_output_root_mean_squared_error: 2.3602 - val_loss: 7.4494 - val_y1_output_loss: 2.3967 - val_y2_output_loss: 4.8050 - val_y1_output_root_mean_squared_error: 1.5698 - val_y2_output_root_mean_squared_error: 2.2327
# Epoch 39/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.1809 - y1_output_loss: 2.4118 - y2_output_loss: 4.8016 - y1_output_root_mean_squared_error: 1.5361 - y2_output_root_mean_squared_error: 2.1957 - val_loss: 8.8606 - val_y1_output_loss: 3.6063 - val_y2_output_loss: 4.9498 - val_y1_output_root_mean_squared_error: 1.9323 - val_y2_output_root_mean_squared_error: 2.2642
# Epoch 40/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.9817 - y1_output_loss: 2.2871 - y2_output_loss: 4.6738 - y1_output_root_mean_squared_error: 1.5095 - y2_output_root_mean_squared_error: 2.1687 - val_loss: 6.9329 - val_y1_output_loss: 2.3952 - val_y2_output_loss: 4.3194 - val_y1_output_root_mean_squared_error: 1.5660 - val_y2_output_root_mean_squared_error: 2.1167
# Epoch 41/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.7966 - y1_output_loss: 2.7506 - y2_output_loss: 6.1030 - y1_output_root_mean_squared_error: 1.6488 - y2_output_root_mean_squared_error: 2.4654 - val_loss: 13.7891 - val_y1_output_loss: 4.7756 - val_y2_output_loss: 8.8798 - val_y1_output_root_mean_squared_error: 2.1848 - val_y2_output_root_mean_squared_error: 3.0026
# Epoch 42/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.6405 - y1_output_loss: 2.2711 - y2_output_loss: 4.4122 - y1_output_root_mean_squared_error: 1.5042 - y2_output_root_mean_squared_error: 2.0924 - val_loss: 7.7336 - val_y1_output_loss: 3.2092 - val_y2_output_loss: 4.8649 - val_y1_output_root_mean_squared_error: 1.7277 - val_y2_output_root_mean_squared_error: 2.1791
# Epoch 43/500
# 614/614 [==============================] - 0s 130us/sample - loss: 7.1621 - y1_output_loss: 2.1446 - y2_output_loss: 5.0082 - y1_output_root_mean_squared_error: 1.4711 - y2_output_root_mean_squared_error: 2.2356 - val_loss: 5.6814 - val_y1_output_loss: 1.9802 - val_y2_output_loss: 3.7523 - val_y1_output_root_mean_squared_error: 1.3865 - val_y2_output_root_mean_squared_error: 1.9388
# Epoch 44/500
# 614/614 [==============================] - 0s 131us/sample - loss: 11.6776 - y1_output_loss: 4.3391 - y2_output_loss: 7.3173 - y1_output_root_mean_squared_error: 2.0889 - y2_output_root_mean_squared_error: 2.7045 - val_loss: 7.1557 - val_y1_output_loss: 2.3631 - val_y2_output_loss: 4.6853 - val_y1_output_root_mean_squared_error: 1.5457 - val_y2_output_root_mean_squared_error: 2.1833
# Epoch 45/500
# 614/614 [==============================] - 0s 132us/sample - loss: 8.5465 - y1_output_loss: 2.7197 - y2_output_loss: 5.8991 - y1_output_root_mean_squared_error: 1.6447 - y2_output_root_mean_squared_error: 2.4169 - val_loss: 12.5580 - val_y1_output_loss: 3.5883 - val_y2_output_loss: 9.1775 - val_y1_output_root_mean_squared_error: 1.8499 - val_y2_output_root_mean_squared_error: 3.0225
# Epoch 46/500
# 614/614 [==============================] - 0s 130us/sample - loss: 7.9125 - y1_output_loss: 2.3402 - y2_output_loss: 5.5183 - y1_output_root_mean_squared_error: 1.5367 - y2_output_root_mean_squared_error: 2.3561 - val_loss: 5.6268 - val_y1_output_loss: 2.3644 - val_y2_output_loss: 3.3312 - val_y1_output_root_mean_squared_error: 1.5129 - val_y2_output_root_mean_squared_error: 1.8270
# Epoch 47/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.7019 - y1_output_loss: 2.3393 - y2_output_loss: 5.2911 - y1_output_root_mean_squared_error: 1.5368 - y2_output_root_mean_squared_error: 2.3109 - val_loss: 4.2827 - val_y1_output_loss: 1.5228 - val_y2_output_loss: 2.7030 - val_y1_output_root_mean_squared_error: 1.2290 - val_y2_output_root_mean_squared_error: 1.6650
# Epoch 48/500
# 614/614 [==============================] - 0s 130us/sample - loss: 7.1162 - y1_output_loss: 2.0834 - y2_output_loss: 5.0081 - y1_output_root_mean_squared_error: 1.4374 - y2_output_root_mean_squared_error: 2.2472 - val_loss: 6.2667 - val_y1_output_loss: 1.6751 - val_y2_output_loss: 4.4716 - val_y1_output_root_mean_squared_error: 1.2859 - val_y2_output_root_mean_squared_error: 2.1478
# Epoch 49/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.3624 - y1_output_loss: 1.9219 - y2_output_loss: 4.4504 - y1_output_root_mean_squared_error: 1.3899 - y2_output_root_mean_squared_error: 2.1049 - val_loss: 6.3055 - val_y1_output_loss: 1.9530 - val_y2_output_loss: 4.1349 - val_y1_output_root_mean_squared_error: 1.4193 - val_y2_output_root_mean_squared_error: 2.0714
# Epoch 50/500
# 614/614 [==============================] - 0s 137us/sample - loss: 5.7145 - y1_output_loss: 1.7709 - y2_output_loss: 3.9256 - y1_output_root_mean_squared_error: 1.3363 - y2_output_root_mean_squared_error: 1.9821 - val_loss: 9.9264 - val_y1_output_loss: 2.1317 - val_y2_output_loss: 7.9224 - val_y1_output_root_mean_squared_error: 1.4149 - val_y2_output_root_mean_squared_error: 2.8151
# Epoch 51/500
# 614/614 [==============================] - 0s 137us/sample - loss: 6.0943 - y1_output_loss: 1.6860 - y2_output_loss: 4.3586 - y1_output_root_mean_squared_error: 1.3042 - y2_output_root_mean_squared_error: 2.0961 - val_loss: 5.5420 - val_y1_output_loss: 1.8895 - val_y2_output_loss: 3.6731 - val_y1_output_root_mean_squared_error: 1.3588 - val_y2_output_root_mean_squared_error: 1.9224
# Epoch 52/500
# 614/614 [==============================] - 0s 130us/sample - loss: 5.5983 - y1_output_loss: 1.5640 - y2_output_loss: 4.0084 - y1_output_root_mean_squared_error: 1.2468 - y2_output_root_mean_squared_error: 2.0109 - val_loss: 8.9002 - val_y1_output_loss: 3.6640 - val_y2_output_loss: 5.0505 - val_y1_output_root_mean_squared_error: 1.9301 - val_y2_output_root_mean_squared_error: 2.2749
# Epoch 53/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.4707 - y1_output_loss: 2.0459 - y2_output_loss: 4.3839 - y1_output_root_mean_squared_error: 1.4340 - y2_output_root_mean_squared_error: 2.1010 - val_loss: 3.3099 - val_y1_output_loss: 1.1751 - val_y2_output_loss: 2.1723 - val_y1_output_root_mean_squared_error: 1.0592 - val_y2_output_root_mean_squared_error: 1.4792
# Epoch 54/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.5652 - y1_output_loss: 1.5042 - y2_output_loss: 3.0308 - y1_output_root_mean_squared_error: 1.2298 - y2_output_root_mean_squared_error: 1.7472 - val_loss: 4.4662 - val_y1_output_loss: 1.6327 - val_y2_output_loss: 2.9421 - val_y1_output_root_mean_squared_error: 1.2381 - val_y2_output_root_mean_squared_error: 1.7127
# Epoch 55/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.5367 - y1_output_loss: 1.6530 - y2_output_loss: 3.8553 - y1_output_root_mean_squared_error: 1.2905 - y2_output_root_mean_squared_error: 1.9676 - val_loss: 4.9324 - val_y1_output_loss: 1.4020 - val_y2_output_loss: 3.6733 - val_y1_output_root_mean_squared_error: 1.1432 - val_y2_output_root_mean_squared_error: 1.9041
# Epoch 56/500
# 614/614 [==============================] - 0s 137us/sample - loss: 5.4849 - y1_output_loss: 1.4569 - y2_output_loss: 4.0419 - y1_output_root_mean_squared_error: 1.2040 - y2_output_root_mean_squared_error: 2.0088 - val_loss: 14.7882 - val_y1_output_loss: 2.7340 - val_y2_output_loss: 12.1417 - val_y1_output_root_mean_squared_error: 1.6145 - val_y2_output_root_mean_squared_error: 3.4902
# Epoch 57/500
# 614/614 [==============================] - 0s 142us/sample - loss: 5.1985 - y1_output_loss: 1.4889 - y2_output_loss: 3.7101 - y1_output_root_mean_squared_error: 1.2245 - y2_output_root_mean_squared_error: 1.9233 - val_loss: 3.3432 - val_y1_output_loss: 1.1010 - val_y2_output_loss: 2.2279 - val_y1_output_root_mean_squared_error: 1.0424 - val_y2_output_root_mean_squared_error: 1.5022
# Epoch 58/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.5390 - y1_output_loss: 1.1709 - y2_output_loss: 3.3895 - y1_output_root_mean_squared_error: 1.0871 - y2_output_root_mean_squared_error: 1.8322 - val_loss: 3.6782 - val_y1_output_loss: 1.1882 - val_y2_output_loss: 2.5595 - val_y1_output_root_mean_squared_error: 1.0613 - val_y2_output_root_mean_squared_error: 1.5974
# Epoch 59/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.3300 - y1_output_loss: 1.7889 - y2_output_loss: 4.5401 - y1_output_root_mean_squared_error: 1.3416 - y2_output_root_mean_squared_error: 2.1284 - val_loss: 5.2591 - val_y1_output_loss: 1.3180 - val_y2_output_loss: 3.7738 - val_y1_output_root_mean_squared_error: 1.1624 - val_y2_output_root_mean_squared_error: 1.9768
# Epoch 60/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.6886 - y1_output_loss: 1.2971 - y2_output_loss: 3.3651 - y1_output_root_mean_squared_error: 1.1384 - y2_output_root_mean_squared_error: 1.8419 - val_loss: 3.3197 - val_y1_output_loss: 1.1939 - val_y2_output_loss: 2.0670 - val_y1_output_root_mean_squared_error: 1.1002 - val_y2_output_root_mean_squared_error: 1.4524
# Epoch 61/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.3114 - y1_output_loss: 1.2844 - y2_output_loss: 3.0318 - y1_output_root_mean_squared_error: 1.1292 - y2_output_root_mean_squared_error: 1.7425 - val_loss: 14.7159 - val_y1_output_loss: 6.2213 - val_y2_output_loss: 7.9533 - val_y1_output_root_mean_squared_error: 2.5423 - val_y2_output_root_mean_squared_error: 2.8728
# Epoch 62/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.0767 - y1_output_loss: 1.7077 - y2_output_loss: 4.3649 - y1_output_root_mean_squared_error: 1.3033 - y2_output_root_mean_squared_error: 2.0924 - val_loss: 9.4944 - val_y1_output_loss: 4.1081 - val_y2_output_loss: 5.0518 - val_y1_output_root_mean_squared_error: 2.0619 - val_y2_output_root_mean_squared_error: 2.2898
# Epoch 63/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.4884 - y1_output_loss: 1.3070 - y2_output_loss: 3.2384 - y1_output_root_mean_squared_error: 1.1471 - y2_output_root_mean_squared_error: 1.7812 - val_loss: 15.3002 - val_y1_output_loss: 3.9042 - val_y2_output_loss: 10.9540 - val_y1_output_root_mean_squared_error: 2.0092 - val_y2_output_root_mean_squared_error: 3.3561
# Epoch 64/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.4419 - y1_output_loss: 1.3564 - y2_output_loss: 4.0731 - y1_output_root_mean_squared_error: 1.1668 - y2_output_root_mean_squared_error: 2.0200 - val_loss: 7.3988 - val_y1_output_loss: 2.1998 - val_y2_output_loss: 4.9820 - val_y1_output_root_mean_squared_error: 1.4983 - val_y2_output_root_mean_squared_error: 2.2702
# Epoch 65/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.5226 - y1_output_loss: 0.9836 - y2_output_loss: 2.5241 - y1_output_root_mean_squared_error: 0.9925 - y2_output_root_mean_squared_error: 1.5929 - val_loss: 3.0894 - val_y1_output_loss: 0.9782 - val_y2_output_loss: 2.0694 - val_y1_output_root_mean_squared_error: 0.9817 - val_y2_output_root_mean_squared_error: 1.4580
# Epoch 66/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.2700 - y1_output_loss: 1.1729 - y2_output_loss: 3.0842 - y1_output_root_mean_squared_error: 1.0877 - y2_output_root_mean_squared_error: 1.7570 - val_loss: 3.5873 - val_y1_output_loss: 0.8263 - val_y2_output_loss: 2.6918 - val_y1_output_root_mean_squared_error: 0.9087 - val_y2_output_root_mean_squared_error: 1.6618
# Epoch 67/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.9253 - y1_output_loss: 0.9860 - y2_output_loss: 2.9142 - y1_output_root_mean_squared_error: 0.9956 - y2_output_root_mean_squared_error: 1.7129 - val_loss: 3.9884 - val_y1_output_loss: 0.6600 - val_y2_output_loss: 3.2644 - val_y1_output_root_mean_squared_error: 0.8074 - val_y2_output_root_mean_squared_error: 1.8266
# Epoch 68/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.6631 - y1_output_loss: 0.9891 - y2_output_loss: 2.6689 - y1_output_root_mean_squared_error: 0.9974 - y2_output_root_mean_squared_error: 1.6335 - val_loss: 2.2084 - val_y1_output_loss: 0.6042 - val_y2_output_loss: 1.5605 - val_y1_output_root_mean_squared_error: 0.7716 - val_y2_output_root_mean_squared_error: 1.2701
# Epoch 69/500
# 614/614 [==============================] - 0s 139us/sample - loss: 3.1059 - y1_output_loss: 0.6774 - y2_output_loss: 2.4258 - y1_output_root_mean_squared_error: 0.8254 - y2_output_root_mean_squared_error: 1.5571 - val_loss: 9.1478 - val_y1_output_loss: 1.5864 - val_y2_output_loss: 7.3179 - val_y1_output_root_mean_squared_error: 1.2647 - val_y2_output_root_mean_squared_error: 2.7474
# Epoch 70/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.7951 - y1_output_loss: 1.0469 - y2_output_loss: 2.8050 - y1_output_root_mean_squared_error: 1.0032 - y2_output_root_mean_squared_error: 1.6699 - val_loss: 4.5776 - val_y1_output_loss: 1.9161 - val_y2_output_loss: 2.5655 - val_y1_output_root_mean_squared_error: 1.3932 - val_y2_output_root_mean_squared_error: 1.6238
# Epoch 71/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.3623 - y1_output_loss: 0.8145 - y2_output_loss: 2.5198 - y1_output_root_mean_squared_error: 0.9055 - y2_output_root_mean_squared_error: 1.5945 - val_loss: 2.1267 - val_y1_output_loss: 0.5900 - val_y2_output_loss: 1.4825 - val_y1_output_root_mean_squared_error: 0.7714 - val_y2_output_root_mean_squared_error: 1.2376
# Epoch 72/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.6525 - y1_output_loss: 0.8872 - y2_output_loss: 2.7631 - y1_output_root_mean_squared_error: 0.9437 - y2_output_root_mean_squared_error: 1.6619 - val_loss: 2.4798 - val_y1_output_loss: 0.6712 - val_y2_output_loss: 1.7565 - val_y1_output_root_mean_squared_error: 0.8131 - val_y2_output_root_mean_squared_error: 1.3486
# Epoch 73/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.0402 - y1_output_loss: 0.7934 - y2_output_loss: 2.3060 - y1_output_root_mean_squared_error: 0.8832 - y2_output_root_mean_squared_error: 1.5034 - val_loss: 4.5811 - val_y1_output_loss: 1.4730 - val_y2_output_loss: 3.1205 - val_y1_output_root_mean_squared_error: 1.1926 - val_y2_output_root_mean_squared_error: 1.7773
# Epoch 74/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.3978 - y1_output_loss: 0.7819 - y2_output_loss: 2.6909 - y1_output_root_mean_squared_error: 0.8823 - y2_output_root_mean_squared_error: 1.6184 - val_loss: 17.9139 - val_y1_output_loss: 4.6069 - val_y2_output_loss: 13.6412 - val_y1_output_root_mean_squared_error: 2.0887 - val_y2_output_root_mean_squared_error: 3.6812
# Epoch 75/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.4006 - y1_output_loss: 1.4160 - y2_output_loss: 3.9873 - y1_output_root_mean_squared_error: 1.1892 - y2_output_root_mean_squared_error: 1.9966 - val_loss: 3.7040 - val_y1_output_loss: 0.5890 - val_y2_output_loss: 2.9936 - val_y1_output_root_mean_squared_error: 0.7741 - val_y2_output_root_mean_squared_error: 1.7621
# Epoch 76/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.6132 - y1_output_loss: 0.6113 - y2_output_loss: 1.9987 - y1_output_root_mean_squared_error: 0.7774 - y2_output_root_mean_squared_error: 1.4173 - val_loss: 2.8585 - val_y1_output_loss: 0.7662 - val_y2_output_loss: 2.0288 - val_y1_output_root_mean_squared_error: 0.8734 - val_y2_output_root_mean_squared_error: 1.4476
# Epoch 77/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.1754 - y1_output_loss: 0.7966 - y2_output_loss: 2.3550 - y1_output_root_mean_squared_error: 0.8952 - y2_output_root_mean_squared_error: 1.5408 - val_loss: 3.2135 - val_y1_output_loss: 0.5377 - val_y2_output_loss: 2.5749 - val_y1_output_root_mean_squared_error: 0.7431 - val_y2_output_root_mean_squared_error: 1.6313
# Epoch 78/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.6366 - y1_output_loss: 0.9051 - y2_output_loss: 2.7011 - y1_output_root_mean_squared_error: 0.9557 - y2_output_root_mean_squared_error: 1.6502 - val_loss: 2.3811 - val_y1_output_loss: 0.4542 - val_y2_output_loss: 1.8609 - val_y1_output_root_mean_squared_error: 0.6795 - val_y2_output_root_mean_squared_error: 1.3854
# Epoch 79/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.3205 - y1_output_loss: 0.7733 - y2_output_loss: 2.5889 - y1_output_root_mean_squared_error: 0.8633 - y2_output_root_mean_squared_error: 1.6047 - val_loss: 28.9652 - val_y1_output_loss: 11.2853 - val_y2_output_loss: 16.8204 - val_y1_output_root_mean_squared_error: 3.4130 - val_y2_output_root_mean_squared_error: 4.1613
# Epoch 80/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.1323 - y1_output_loss: 1.5055 - y2_output_loss: 3.6042 - y1_output_root_mean_squared_error: 1.2315 - y2_output_root_mean_squared_error: 1.9015 - val_loss: 3.4311 - val_y1_output_loss: 0.5127 - val_y2_output_loss: 2.8243 - val_y1_output_root_mean_squared_error: 0.7119 - val_y2_output_root_mean_squared_error: 1.7100
# Epoch 81/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.8358 - y1_output_loss: 0.9900 - y2_output_loss: 2.8278 - y1_output_root_mean_squared_error: 0.9990 - y2_output_root_mean_squared_error: 1.6846 - val_loss: 3.4651 - val_y1_output_loss: 1.4585 - val_y2_output_loss: 1.9290 - val_y1_output_root_mean_squared_error: 1.2189 - val_y2_output_root_mean_squared_error: 1.4069
# Epoch 82/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.1757 - y1_output_loss: 0.7837 - y2_output_loss: 2.3669 - y1_output_root_mean_squared_error: 0.8875 - y2_output_root_mean_squared_error: 1.5453 - val_loss: 2.1890 - val_y1_output_loss: 0.7009 - val_y2_output_loss: 1.4829 - val_y1_output_root_mean_squared_error: 0.8228 - val_y2_output_root_mean_squared_error: 1.2296
# Epoch 83/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.9155 - y1_output_loss: 0.6947 - y2_output_loss: 2.2007 - y1_output_root_mean_squared_error: 0.8341 - y2_output_root_mean_squared_error: 1.4899 - val_loss: 1.9323 - val_y1_output_loss: 0.5242 - val_y2_output_loss: 1.3772 - val_y1_output_root_mean_squared_error: 0.7195 - val_y2_output_root_mean_squared_error: 1.1894
# Epoch 84/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.6486 - y1_output_loss: 0.8668 - y2_output_loss: 2.7704 - y1_output_root_mean_squared_error: 0.9326 - y2_output_root_mean_squared_error: 1.6670 - val_loss: 5.0437 - val_y1_output_loss: 1.1407 - val_y2_output_loss: 3.7728 - val_y1_output_root_mean_squared_error: 1.0693 - val_y2_output_root_mean_squared_error: 1.9749
# Epoch 85/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.6211 - y1_output_loss: 0.8823 - y2_output_loss: 2.7137 - y1_output_root_mean_squared_error: 0.9435 - y2_output_root_mean_squared_error: 1.6526 - val_loss: 2.1851 - val_y1_output_loss: 0.6189 - val_y2_output_loss: 1.4987 - val_y1_output_root_mean_squared_error: 0.8001 - val_y2_output_root_mean_squared_error: 1.2429
# Epoch 86/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.6950 - y1_output_loss: 0.6745 - y2_output_loss: 2.0085 - y1_output_root_mean_squared_error: 0.8236 - y2_output_root_mean_squared_error: 1.4201 - val_loss: 2.2935 - val_y1_output_loss: 0.6058 - val_y2_output_loss: 1.6215 - val_y1_output_root_mean_squared_error: 0.7835 - val_y2_output_root_mean_squared_error: 1.2960
# Epoch 87/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.5677 - y1_output_loss: 0.6641 - y2_output_loss: 1.8854 - y1_output_root_mean_squared_error: 0.8163 - y2_output_root_mean_squared_error: 1.3789 - val_loss: 2.0020 - val_y1_output_loss: 0.4887 - val_y2_output_loss: 1.4961 - val_y1_output_root_mean_squared_error: 0.6860 - val_y2_output_root_mean_squared_error: 1.2375
# Epoch 88/500
# 614/614 [==============================] - 0s 142us/sample - loss: 2.6796 - y1_output_loss: 0.6219 - y2_output_loss: 2.0497 - y1_output_root_mean_squared_error: 0.7895 - y2_output_root_mean_squared_error: 1.4340 - val_loss: 7.5064 - val_y1_output_loss: 1.5358 - val_y2_output_loss: 5.8541 - val_y1_output_root_mean_squared_error: 1.2399 - val_y2_output_root_mean_squared_error: 2.4431
# Epoch 89/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.5661 - y1_output_loss: 0.6288 - y2_output_loss: 1.9331 - y1_output_root_mean_squared_error: 0.7964 - y2_output_root_mean_squared_error: 1.3899 - val_loss: 5.5378 - val_y1_output_loss: 0.8727 - val_y2_output_loss: 4.5651 - val_y1_output_root_mean_squared_error: 0.9267 - val_y2_output_root_mean_squared_error: 2.1631
# Epoch 90/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.4576 - y1_output_loss: 1.1623 - y2_output_loss: 3.2994 - y1_output_root_mean_squared_error: 1.0733 - y2_output_root_mean_squared_error: 1.8182 - val_loss: 7.1472 - val_y1_output_loss: 1.6119 - val_y2_output_loss: 5.3140 - val_y1_output_root_mean_squared_error: 1.2776 - val_y2_output_root_mean_squared_error: 2.3484
# Epoch 91/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.5526 - y1_output_loss: 0.6771 - y2_output_loss: 1.8910 - y1_output_root_mean_squared_error: 0.8114 - y2_output_root_mean_squared_error: 1.3763 - val_loss: 3.4907 - val_y1_output_loss: 1.1287 - val_y2_output_loss: 2.4117 - val_y1_output_root_mean_squared_error: 1.0546 - val_y2_output_root_mean_squared_error: 1.5422
# Epoch 92/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.8693 - y1_output_loss: 0.6934 - y2_output_loss: 2.1702 - y1_output_root_mean_squared_error: 0.8324 - y2_output_root_mean_squared_error: 1.4753 - val_loss: 2.0974 - val_y1_output_loss: 0.4732 - val_y2_output_loss: 1.5602 - val_y1_output_root_mean_squared_error: 0.6934 - val_y2_output_root_mean_squared_error: 1.2715
# Epoch 93/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.7714 - y1_output_loss: 0.5924 - y2_output_loss: 2.1546 - y1_output_root_mean_squared_error: 0.7726 - y2_output_root_mean_squared_error: 1.4746 - val_loss: 1.8331 - val_y1_output_loss: 0.5081 - val_y2_output_loss: 1.2914 - val_y1_output_root_mean_squared_error: 0.7105 - val_y2_output_root_mean_squared_error: 1.1525
# Epoch 94/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.6527 - y1_output_loss: 0.6686 - y2_output_loss: 1.9672 - y1_output_root_mean_squared_error: 0.8208 - y2_output_root_mean_squared_error: 1.4068 - val_loss: 2.0863 - val_y1_output_loss: 0.4732 - val_y2_output_loss: 1.5497 - val_y1_output_root_mean_squared_error: 0.6958 - val_y2_output_root_mean_squared_error: 1.2657
# Epoch 95/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.1797 - y1_output_loss: 1.0337 - y2_output_loss: 3.1481 - y1_output_root_mean_squared_error: 1.0193 - y2_output_root_mean_squared_error: 1.7722 - val_loss: 1.9372 - val_y1_output_loss: 0.5083 - val_y2_output_loss: 1.3818 - val_y1_output_root_mean_squared_error: 0.7160 - val_y2_output_root_mean_squared_error: 1.1936
# Epoch 96/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.6315 - y1_output_loss: 0.8125 - y2_output_loss: 2.7909 - y1_output_root_mean_squared_error: 0.9042 - y2_output_root_mean_squared_error: 1.6775 - val_loss: 5.3865 - val_y1_output_loss: 1.6886 - val_y2_output_loss: 3.6241 - val_y1_output_root_mean_squared_error: 1.3119 - val_y2_output_root_mean_squared_error: 1.9145
# Epoch 97/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.3369 - y1_output_loss: 0.5754 - y2_output_loss: 1.7479 - y1_output_root_mean_squared_error: 0.7570 - y2_output_root_mean_squared_error: 1.3281 - val_loss: 2.0736 - val_y1_output_loss: 0.6222 - val_y2_output_loss: 1.4025 - val_y1_output_root_mean_squared_error: 0.7875 - val_y2_output_root_mean_squared_error: 1.2056
# Epoch 98/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.0018 - y1_output_loss: 0.6482 - y2_output_loss: 2.3253 - y1_output_root_mean_squared_error: 0.8087 - y2_output_root_mean_squared_error: 1.5322 - val_loss: 2.0067 - val_y1_output_loss: 0.5798 - val_y2_output_loss: 1.3664 - val_y1_output_root_mean_squared_error: 0.7753 - val_y2_output_root_mean_squared_error: 1.1856
# Epoch 99/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.1743 - y1_output_loss: 0.5291 - y2_output_loss: 1.6343 - y1_output_root_mean_squared_error: 0.7292 - y2_output_root_mean_squared_error: 1.2816 - val_loss: 1.6989 - val_y1_output_loss: 0.3171 - val_y2_output_loss: 1.3340 - val_y1_output_root_mean_squared_error: 0.5678 - val_y2_output_root_mean_squared_error: 1.1732
# Epoch 100/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.1083 - y1_output_loss: 0.4549 - y2_output_loss: 1.6630 - y1_output_root_mean_squared_error: 0.6744 - y2_output_root_mean_squared_error: 1.2859 - val_loss: 5.1171 - val_y1_output_loss: 1.0630 - val_y2_output_loss: 4.1569 - val_y1_output_root_mean_squared_error: 1.0191 - val_y2_output_root_mean_squared_error: 2.0196
# Epoch 101/500
# 614/614 [==============================] - 0s 139us/sample - loss: 1.8854 - y1_output_loss: 0.4859 - y2_output_loss: 1.4108 - y1_output_root_mean_squared_error: 0.6992 - y2_output_root_mean_squared_error: 1.1818 - val_loss: 2.3816 - val_y1_output_loss: 0.6738 - val_y2_output_loss: 1.6368 - val_y1_output_root_mean_squared_error: 0.8297 - val_y2_output_root_mean_squared_error: 1.3012
# Epoch 102/500
# 614/614 [==============================] - 0s 138us/sample - loss: 1.9992 - y1_output_loss: 0.5202 - y2_output_loss: 1.4638 - y1_output_root_mean_squared_error: 0.7242 - y2_output_root_mean_squared_error: 1.2144 - val_loss: 1.5978 - val_y1_output_loss: 0.3981 - val_y2_output_loss: 1.1497 - val_y1_output_root_mean_squared_error: 0.6383 - val_y2_output_root_mean_squared_error: 1.0910
# Epoch 103/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.6642 - y1_output_loss: 0.5383 - y2_output_loss: 2.1759 - y1_output_root_mean_squared_error: 0.7326 - y2_output_root_mean_squared_error: 1.4586 - val_loss: 14.7001 - val_y1_output_loss: 4.2328 - val_y2_output_loss: 9.9959 - val_y1_output_root_mean_squared_error: 2.0950 - val_y2_output_root_mean_squared_error: 3.2111
# Epoch 104/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.7465 - y1_output_loss: 0.6535 - y2_output_loss: 2.0806 - y1_output_root_mean_squared_error: 0.8114 - y2_output_root_mean_squared_error: 1.4450 - val_loss: 2.2370 - val_y1_output_loss: 0.6667 - val_y2_output_loss: 1.5833 - val_y1_output_root_mean_squared_error: 0.7954 - val_y2_output_root_mean_squared_error: 1.2667
# Epoch 105/500
# 614/614 [==============================] - 0s 132us/sample - loss: 1.9980 - y1_output_loss: 0.5325 - y2_output_loss: 1.4664 - y1_output_root_mean_squared_error: 0.7249 - y2_output_root_mean_squared_error: 1.2135 - val_loss: 2.4539 - val_y1_output_loss: 0.7856 - val_y2_output_loss: 1.6064 - val_y1_output_root_mean_squared_error: 0.9006 - val_y2_output_root_mean_squared_error: 1.2817
# Epoch 106/500
# 614/614 [==============================] - 0s 138us/sample - loss: 2.3990 - y1_output_loss: 0.5230 - y2_output_loss: 1.8688 - y1_output_root_mean_squared_error: 0.7219 - y2_output_root_mean_squared_error: 1.3704 - val_loss: 2.1570 - val_y1_output_loss: 0.3962 - val_y2_output_loss: 1.7160 - val_y1_output_root_mean_squared_error: 0.6298 - val_y2_output_root_mean_squared_error: 1.3268
# Epoch 107/500
# 614/614 [==============================] - 0s 133us/sample - loss: 5.6847 - y1_output_loss: 1.7292 - y2_output_loss: 3.9368 - y1_output_root_mean_squared_error: 1.3194 - y2_output_root_mean_squared_error: 1.9859 - val_loss: 3.0719 - val_y1_output_loss: 0.8218 - val_y2_output_loss: 2.2201 - val_y1_output_root_mean_squared_error: 0.8835 - val_y2_output_root_mean_squared_error: 1.5137
# Epoch 108/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.2382 - y1_output_loss: 0.5103 - y2_output_loss: 1.7265 - y1_output_root_mean_squared_error: 0.7138 - y2_output_root_mean_squared_error: 1.3148 - val_loss: 4.0414 - val_y1_output_loss: 1.5215 - val_y2_output_loss: 2.4246 - val_y1_output_root_mean_squared_error: 1.2416 - val_y2_output_root_mean_squared_error: 1.5811
# Epoch 109/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.5388 - y1_output_loss: 0.6236 - y2_output_loss: 2.2747 - y1_output_root_mean_squared_error: 0.7550 - y2_output_root_mean_squared_error: 1.4031 - val_loss: 54.7509 - val_y1_output_loss: 12.3671 - val_y2_output_loss: 41.9243 - val_y1_output_root_mean_squared_error: 3.5115 - val_y2_output_root_mean_squared_error: 6.5131
# Epoch 110/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.5095 - y1_output_loss: 2.5786 - y2_output_loss: 4.8784 - y1_output_root_mean_squared_error: 1.6124 - y2_output_root_mean_squared_error: 2.2158 - val_loss: 1.7172 - val_y1_output_loss: 0.3981 - val_y2_output_loss: 1.3024 - val_y1_output_root_mean_squared_error: 0.6174 - val_y2_output_root_mean_squared_error: 1.1559
# Epoch 111/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.5158 - y1_output_loss: 0.5660 - y2_output_loss: 1.9604 - y1_output_root_mean_squared_error: 0.7554 - y2_output_root_mean_squared_error: 1.3947 - val_loss: 3.6401 - val_y1_output_loss: 0.7571 - val_y2_output_loss: 2.8315 - val_y1_output_root_mean_squared_error: 0.8618 - val_y2_output_root_mean_squared_error: 1.7022
# Epoch 112/500
# 614/614 [==============================] - 0s 136us/sample - loss: 2.1964 - y1_output_loss: 0.4989 - y2_output_loss: 1.7084 - y1_output_root_mean_squared_error: 0.7058 - y2_output_root_mean_squared_error: 1.3032 - val_loss: 4.7701 - val_y1_output_loss: 0.4513 - val_y2_output_loss: 4.1998 - val_y1_output_root_mean_squared_error: 0.6810 - val_y2_output_root_mean_squared_error: 2.0752
# Epoch 113/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.6761 - y1_output_loss: 0.5936 - y2_output_loss: 2.1004 - y1_output_root_mean_squared_error: 0.7705 - y2_output_root_mean_squared_error: 1.4431 - val_loss: 4.7904 - val_y1_output_loss: 0.3758 - val_y2_output_loss: 4.2778 - val_y1_output_root_mean_squared_error: 0.6218 - val_y2_output_root_mean_squared_error: 2.0985
# Epoch 114/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.8186 - y1_output_loss: 0.6692 - y2_output_loss: 2.1477 - y1_output_root_mean_squared_error: 0.8114 - y2_output_root_mean_squared_error: 1.4698 - val_loss: 4.5483 - val_y1_output_loss: 1.7111 - val_y2_output_loss: 2.6848 - val_y1_output_root_mean_squared_error: 1.3324 - val_y2_output_root_mean_squared_error: 1.6653
# Epoch 115/500
# 614/614 [==============================] - 0s 131us/sample - loss: 1.7598 - y1_output_loss: 0.3699 - y2_output_loss: 1.3894 - y1_output_root_mean_squared_error: 0.6091 - y2_output_root_mean_squared_error: 1.1785 - val_loss: 3.7021 - val_y1_output_loss: 0.4149 - val_y2_output_loss: 3.1846 - val_y1_output_root_mean_squared_error: 0.6472 - val_y2_output_root_mean_squared_error: 1.8120
# Epoch 116/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.5421 - y1_output_loss: 0.6288 - y2_output_loss: 1.9357 - y1_output_root_mean_squared_error: 0.7958 - y2_output_root_mean_squared_error: 1.3816 - val_loss: 7.0700 - val_y1_output_loss: 0.9636 - val_y2_output_loss: 5.9140 - val_y1_output_root_mean_squared_error: 0.9968 - val_y2_output_root_mean_squared_error: 2.4650
# Epoch 117/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.2771 - y1_output_loss: 0.5357 - y2_output_loss: 1.7448 - y1_output_root_mean_squared_error: 0.7348 - y2_output_root_mean_squared_error: 1.3180 - val_loss: 2.6227 - val_y1_output_loss: 0.5752 - val_y2_output_loss: 2.0046 - val_y1_output_root_mean_squared_error: 0.7579 - val_y2_output_root_mean_squared_error: 1.4312
# Epoch 118/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.3970 - y1_output_loss: 0.4960 - y2_output_loss: 1.8847 - y1_output_root_mean_squared_error: 0.7054 - y2_output_root_mean_squared_error: 1.3782 - val_loss: 2.5610 - val_y1_output_loss: 0.4714 - val_y2_output_loss: 2.0217 - val_y1_output_root_mean_squared_error: 0.6908 - val_y2_output_root_mean_squared_error: 1.4435
# Epoch 119/500
# 614/614 [==============================] - 0s 137us/sample - loss: 1.8116 - y1_output_loss: 0.4714 - y2_output_loss: 1.3829 - y1_output_root_mean_squared_error: 0.6830 - y2_output_root_mean_squared_error: 1.1598 - val_loss: 10.2525 - val_y1_output_loss: 1.8022 - val_y2_output_loss: 8.2214 - val_y1_output_root_mean_squared_error: 1.3624 - val_y2_output_root_mean_squared_error: 2.8976
# Epoch 120/500
# 614/614 [==============================] - 0s 137us/sample - loss: 2.4351 - y1_output_loss: 0.5681 - y2_output_loss: 1.8513 - y1_output_root_mean_squared_error: 0.7564 - y2_output_root_mean_squared_error: 1.3649 - val_loss: 1.8645 - val_y1_output_loss: 0.4471 - val_y2_output_loss: 1.3771 - val_y1_output_root_mean_squared_error: 0.6726 - val_y2_output_root_mean_squared_error: 1.1883
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4687 - y1_output_loss: 0.1304 - y2_output_loss: 0.3413 - y1_output_root_mean_squared_error: 0.3622 - y2_output_root_mean_squared_error: 0.5810 - val_loss: 0.8633 - val_y1_output_loss: 0.2324 - val_y2_output_loss: 0.6636 - val_y1_output_root_mean_squared_error: 0.4828 - val_y2_output_root_mean_squared_error: 0.7939
# Epoch 462/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4242 - y1_output_loss: 0.1186 - y2_output_loss: 0.3043 - y1_output_root_mean_squared_error: 0.3454 - y2_output_root_mean_squared_error: 0.5521 - val_loss: 1.2947 - val_y1_output_loss: 0.3304 - val_y2_output_loss: 0.9676 - val_y1_output_root_mean_squared_error: 0.5774 - val_y2_output_root_mean_squared_error: 0.9804
# Epoch 463/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4670 - y1_output_loss: 0.1489 - y2_output_loss: 0.3321 - y1_output_root_mean_squared_error: 0.3724 - y2_output_root_mean_squared_error: 0.5729 - val_loss: 4.1596 - val_y1_output_loss: 1.2063 - val_y2_output_loss: 2.8758 - val_y1_output_root_mean_squared_error: 1.0990 - val_y2_output_root_mean_squared_error: 1.7180
# Epoch 464/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.6002 - y1_output_loss: 0.1715 - y2_output_loss: 0.4262 - y1_output_root_mean_squared_error: 0.4155 - y2_output_root_mean_squared_error: 0.6539 - val_loss: 1.6948 - val_y1_output_loss: 0.4855 - val_y2_output_loss: 1.2362 - val_y1_output_root_mean_squared_error: 0.7063 - val_y2_output_root_mean_squared_error: 1.0936
# Epoch 465/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4141 - y1_output_loss: 0.1282 - y2_output_loss: 0.2856 - y1_output_root_mean_squared_error: 0.3586 - y2_output_root_mean_squared_error: 0.5343 - val_loss: 0.8299 - val_y1_output_loss: 0.1707 - val_y2_output_loss: 0.6818 - val_y1_output_root_mean_squared_error: 0.4174 - val_y2_output_root_mean_squared_error: 0.8097
# Epoch 466/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3433 - y1_output_loss: 0.1132 - y2_output_loss: 0.2299 - y1_output_root_mean_squared_error: 0.3374 - y2_output_root_mean_squared_error: 0.4790 - val_loss: 0.6536 - val_y1_output_loss: 0.1832 - val_y2_output_loss: 0.4874 - val_y1_output_root_mean_squared_error: 0.4263 - val_y2_output_root_mean_squared_error: 0.6869
# Epoch 467/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.5694 - y1_output_loss: 0.1675 - y2_output_loss: 0.3968 - y1_output_root_mean_squared_error: 0.4108 - y2_output_root_mean_squared_error: 0.6330 - val_loss: 0.5970 - val_y1_output_loss: 0.1605 - val_y2_output_loss: 0.4601 - val_y1_output_root_mean_squared_error: 0.4069 - val_y2_output_root_mean_squared_error: 0.6568
# Epoch 468/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3679 - y1_output_loss: 0.1181 - y2_output_loss: 0.2510 - y1_output_root_mean_squared_error: 0.3419 - y2_output_root_mean_squared_error: 0.5010 - val_loss: 1.2818 - val_y1_output_loss: 0.4786 - val_y2_output_loss: 0.8072 - val_y1_output_root_mean_squared_error: 0.7000 - val_y2_output_root_mean_squared_error: 0.8898
# Epoch 469/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3597 - y1_output_loss: 0.1222 - y2_output_loss: 0.2350 - y1_output_root_mean_squared_error: 0.3504 - y2_output_root_mean_squared_error: 0.4867 - val_loss: 0.7431 - val_y1_output_loss: 0.2383 - val_y2_output_loss: 0.5301 - val_y1_output_root_mean_squared_error: 0.4942 - val_y2_output_root_mean_squared_error: 0.7063
# Epoch 470/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.2978 - y1_output_loss: 0.0999 - y2_output_loss: 0.1968 - y1_output_root_mean_squared_error: 0.3172 - y2_output_root_mean_squared_error: 0.4440 - val_loss: 0.7013 - val_y1_output_loss: 0.2203 - val_y2_output_loss: 0.4861 - val_y1_output_root_mean_squared_error: 0.4704 - val_y2_output_root_mean_squared_error: 0.6929
# Epoch 471/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3742 - y1_output_loss: 0.1187 - y2_output_loss: 0.2546 - y1_output_root_mean_squared_error: 0.3453 - y2_output_root_mean_squared_error: 0.5050 - val_loss: 0.8021 - val_y1_output_loss: 0.1928 - val_y2_output_loss: 0.6685 - val_y1_output_root_mean_squared_error: 0.4452 - val_y2_output_root_mean_squared_error: 0.7772
# Epoch 472/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.3655 - y1_output_loss: 0.1169 - y2_output_loss: 0.2479 - y1_output_root_mean_squared_error: 0.3425 - y2_output_root_mean_squared_error: 0.4982 - val_loss: 0.7446 - val_y1_output_loss: 0.2618 - val_y2_output_loss: 0.4814 - val_y1_output_root_mean_squared_error: 0.5134 - val_y2_output_root_mean_squared_error: 0.6936
# Epoch 473/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4774 - y1_output_loss: 0.1306 - y2_output_loss: 0.3433 - y1_output_root_mean_squared_error: 0.3629 - y2_output_root_mean_squared_error: 0.5879 - val_loss: 0.6355 - val_y1_output_loss: 0.2346 - val_y2_output_loss: 0.4080 - val_y1_output_root_mean_squared_error: 0.4857 - val_y2_output_root_mean_squared_error: 0.6322
# Epoch 474/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.9642 - y1_output_loss: 0.2525 - y2_output_loss: 0.7109 - y1_output_root_mean_squared_error: 0.4996 - y2_output_root_mean_squared_error: 0.8453 - val_loss: 1.8503 - val_y1_output_loss: 0.8261 - val_y2_output_loss: 1.0067 - val_y1_output_root_mean_squared_error: 0.9235 - val_y2_output_root_mean_squared_error: 0.9987
# Epoch 475/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.5926 - y1_output_loss: 0.1697 - y2_output_loss: 0.4187 - y1_output_root_mean_squared_error: 0.4126 - y2_output_root_mean_squared_error: 0.6499 - val_loss: 0.6527 - val_y1_output_loss: 0.2474 - val_y2_output_loss: 0.4134 - val_y1_output_root_mean_squared_error: 0.4850 - val_y2_output_root_mean_squared_error: 0.6461
# Epoch 476/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4753 - y1_output_loss: 0.1335 - y2_output_loss: 0.3398 - y1_output_root_mean_squared_error: 0.3648 - y2_output_root_mean_squared_error: 0.5850 - val_loss: 0.6669 - val_y1_output_loss: 0.2075 - val_y2_output_loss: 0.4772 - val_y1_output_root_mean_squared_error: 0.4603 - val_y2_output_root_mean_squared_error: 0.6746
# Epoch 477/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4238 - y1_output_loss: 0.1148 - y2_output_loss: 0.3060 - y1_output_root_mean_squared_error: 0.3398 - y2_output_root_mean_squared_error: 0.5553 - val_loss: 0.6882 - val_y1_output_loss: 0.1955 - val_y2_output_loss: 0.5102 - val_y1_output_root_mean_squared_error: 0.4379 - val_y2_output_root_mean_squared_error: 0.7046
# Epoch 478/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3630 - y1_output_loss: 0.1236 - y2_output_loss: 0.2370 - y1_output_root_mean_squared_error: 0.3528 - y2_output_root_mean_squared_error: 0.4884 - val_loss: 0.5802 - val_y1_output_loss: 0.1728 - val_y2_output_loss: 0.4268 - val_y1_output_root_mean_squared_error: 0.4207 - val_y2_output_root_mean_squared_error: 0.6350
# Epoch 479/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3070 - y1_output_loss: 0.0966 - y2_output_loss: 0.2099 - y1_output_root_mean_squared_error: 0.3122 - y2_output_root_mean_squared_error: 0.4577 - val_loss: 0.6124 - val_y1_output_loss: 0.1648 - val_y2_output_loss: 0.4688 - val_y1_output_root_mean_squared_error: 0.4053 - val_y2_output_root_mean_squared_error: 0.6694
# Epoch 480/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4603 - y1_output_loss: 0.1366 - y2_output_loss: 0.3318 - y1_output_root_mean_squared_error: 0.3687 - y2_output_root_mean_squared_error: 0.5695 - val_loss: 1.2133 - val_y1_output_loss: 0.2486 - val_y2_output_loss: 0.9459 - val_y1_output_root_mean_squared_error: 0.4879 - val_y2_output_root_mean_squared_error: 0.9876
# Epoch 481/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3579 - y1_output_loss: 0.1130 - y2_output_loss: 0.2452 - y1_output_root_mean_squared_error: 0.3359 - y2_output_root_mean_squared_error: 0.4950 - val_loss: 0.8248 - val_y1_output_loss: 0.2972 - val_y2_output_loss: 0.5440 - val_y1_output_root_mean_squared_error: 0.5508 - val_y2_output_root_mean_squared_error: 0.7221
# Epoch 482/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4310 - y1_output_loss: 0.1429 - y2_output_loss: 0.2866 - y1_output_root_mean_squared_error: 0.3767 - y2_output_root_mean_squared_error: 0.5377 - val_loss: 0.5603 - val_y1_output_loss: 0.1772 - val_y2_output_loss: 0.3917 - val_y1_output_root_mean_squared_error: 0.4183 - val_y2_output_root_mean_squared_error: 0.6207
# Epoch 483/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4127 - y1_output_loss: 0.1275 - y2_output_loss: 0.2831 - y1_output_root_mean_squared_error: 0.3585 - y2_output_root_mean_squared_error: 0.5331 - val_loss: 0.6385 - val_y1_output_loss: 0.1830 - val_y2_output_loss: 0.4708 - val_y1_output_root_mean_squared_error: 0.4296 - val_y2_output_root_mean_squared_error: 0.6737
# Epoch 484/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.7531 - y1_output_loss: 0.2322 - y2_output_loss: 0.5194 - y1_output_root_mean_squared_error: 0.4825 - y2_output_root_mean_squared_error: 0.7214 - val_loss: 1.4603 - val_y1_output_loss: 0.3945 - val_y2_output_loss: 1.0430 - val_y1_output_root_mean_squared_error: 0.6306 - val_y2_output_root_mean_squared_error: 1.0308
# Epoch 485/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4127 - y1_output_loss: 0.1306 - y2_output_loss: 0.2822 - y1_output_root_mean_squared_error: 0.3612 - y2_output_root_mean_squared_error: 0.5312 - val_loss: 1.1202 - val_y1_output_loss: 0.2606 - val_y2_output_loss: 0.8852 - val_y1_output_root_mean_squared_error: 0.5200 - val_y2_output_root_mean_squared_error: 0.9219
# Epoch 486/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3336 - y1_output_loss: 0.1097 - y2_output_loss: 0.2225 - y1_output_root_mean_squared_error: 0.3319 - y2_output_root_mean_squared_error: 0.4727 - val_loss: 0.6814 - val_y1_output_loss: 0.1960 - val_y2_output_loss: 0.4967 - val_y1_output_root_mean_squared_error: 0.4392 - val_y2_output_root_mean_squared_error: 0.6990
# Epoch 487/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3273 - y1_output_loss: 0.1081 - y2_output_loss: 0.2177 - y1_output_root_mean_squared_error: 0.3299 - y2_output_root_mean_squared_error: 0.4674 - val_loss: 0.7605 - val_y1_output_loss: 0.2376 - val_y2_output_loss: 0.5214 - val_y1_output_root_mean_squared_error: 0.4870 - val_y2_output_root_mean_squared_error: 0.7235
# Epoch 488/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3280 - y1_output_loss: 0.1034 - y2_output_loss: 0.2218 - y1_output_root_mean_squared_error: 0.3228 - y2_output_root_mean_squared_error: 0.4731 - val_loss: 0.5587 - val_y1_output_loss: 0.1726 - val_y2_output_loss: 0.4070 - val_y1_output_root_mean_squared_error: 0.4216 - val_y2_output_root_mean_squared_error: 0.6172
# Epoch 489/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3745 - y1_output_loss: 0.1218 - y2_output_loss: 0.2521 - y1_output_root_mean_squared_error: 0.3498 - y2_output_root_mean_squared_error: 0.5021 - val_loss: 0.7896 - val_y1_output_loss: 0.2154 - val_y2_output_loss: 0.5917 - val_y1_output_root_mean_squared_error: 0.4655 - val_y2_output_root_mean_squared_error: 0.7570
# Epoch 490/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3705 - y1_output_loss: 0.1139 - y2_output_loss: 0.2570 - y1_output_root_mean_squared_error: 0.3365 - y2_output_root_mean_squared_error: 0.5072 - val_loss: 0.8458 - val_y1_output_loss: 0.3878 - val_y2_output_loss: 0.4473 - val_y1_output_root_mean_squared_error: 0.6266 - val_y2_output_root_mean_squared_error: 0.6732
# Epoch 491/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4190 - y1_output_loss: 0.1218 - y2_output_loss: 0.2966 - y1_output_root_mean_squared_error: 0.3501 - y2_output_root_mean_squared_error: 0.5444 - val_loss: 0.6353 - val_y1_output_loss: 0.2086 - val_y2_output_loss: 0.4253 - val_y1_output_root_mean_squared_error: 0.4514 - val_y2_output_root_mean_squared_error: 0.6569
# Epoch 492/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4107 - y1_output_loss: 0.1218 - y2_output_loss: 0.2869 - y1_output_root_mean_squared_error: 0.3494 - y2_output_root_mean_squared_error: 0.5372 - val_loss: 0.8698 - val_y1_output_loss: 0.2923 - val_y2_output_loss: 0.5965 - val_y1_output_root_mean_squared_error: 0.5481 - val_y2_output_root_mean_squared_error: 0.7545
# Epoch 493/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3278 - y1_output_loss: 0.1096 - y2_output_loss: 0.2173 - y1_output_root_mean_squared_error: 0.3307 - y2_output_root_mean_squared_error: 0.4673 - val_loss: 0.6777 - val_y1_output_loss: 0.2465 - val_y2_output_loss: 0.4325 - val_y1_output_root_mean_squared_error: 0.5011 - val_y2_output_root_mean_squared_error: 0.6532
# Epoch 494/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.2848 - y1_output_loss: 0.0950 - y2_output_loss: 0.1915 - y1_output_root_mean_squared_error: 0.3085 - y2_output_root_mean_squared_error: 0.4354 - val_loss: 1.1405 - val_y1_output_loss: 0.2366 - val_y2_output_loss: 0.8813 - val_y1_output_root_mean_squared_error: 0.4807 - val_y2_output_root_mean_squared_error: 0.9536
# Epoch 495/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4486 - y1_output_loss: 0.1433 - y2_output_loss: 0.3071 - y1_output_root_mean_squared_error: 0.3786 - y2_output_root_mean_squared_error: 0.5525 - val_loss: 1.0452 - val_y1_output_loss: 0.3903 - val_y2_output_loss: 0.6605 - val_y1_output_root_mean_squared_error: 0.6249 - val_y2_output_root_mean_squared_error: 0.8091
# Epoch 496/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4797 - y1_output_loss: 0.1351 - y2_output_loss: 0.3423 - y1_output_root_mean_squared_error: 0.3682 - y2_output_root_mean_squared_error: 0.5866 - val_loss: 0.8323 - val_y1_output_loss: 0.2221 - val_y2_output_loss: 0.6109 - val_y1_output_root_mean_squared_error: 0.4669 - val_y2_output_root_mean_squared_error: 0.7838
# Epoch 497/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3562 - y1_output_loss: 0.1276 - y2_output_loss: 0.2298 - y1_output_root_mean_squared_error: 0.3549 - y2_output_root_mean_squared_error: 0.4799 - val_loss: 0.7487 - val_y1_output_loss: 0.2580 - val_y2_output_loss: 0.4916 - val_y1_output_root_mean_squared_error: 0.5003 - val_y2_output_root_mean_squared_error: 0.7060
# Epoch 498/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4072 - y1_output_loss: 0.1120 - y2_output_loss: 0.2972 - y1_output_root_mean_squared_error: 0.3356 - y2_output_root_mean_squared_error: 0.5427 - val_loss: 1.1615 - val_y1_output_loss: 0.4715 - val_y2_output_loss: 0.6771 - val_y1_output_root_mean_squared_error: 0.6837 - val_y2_output_root_mean_squared_error: 0.8331
# Epoch 499/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3484 - y1_output_loss: 0.1155 - y2_output_loss: 0.2301 - y1_output_root_mean_squared_error: 0.3409 - y2_output_root_mean_squared_error: 0.4819 - val_loss: 0.5654 - val_y1_output_loss: 0.1791 - val_y2_output_loss: 0.4006 - val_y1_output_root_mean_squared_error: 0.4263 - val_y2_output_root_mean_squared_error: 0.6194
# Epoch 500/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3005 - y1_output_loss: 0.1059 - y2_output_loss: 0.1931 - y1_output_root_mean_squared_error: 0.3266 - y2_output_root_mean_squared_error: 0.4403 - val_loss: 0.6741 - val_y1_output_loss: 0.1771 - val_y2_output_loss: 0.4979 - val_y1_output_root_mean_squared_error: 0.4190 - val_y2_output_root_mean_squared_error: 0.7061

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 32us/sample - loss: 0.6741 - y1_output_loss: 0.1760 - y2_output_loss: 0.5037 - y1_output_root_mean_squared_error: 0.4190 - y2_output_root_mean_squared_error: 0.7061
# Loss = 0.674101189359442, Y1_loss = 0.17597350478172302, Y1_mse = 0.41903772950172424, Y2_loss = 0.5036717653274536, Y2_mse = 0.7060513496398926

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
